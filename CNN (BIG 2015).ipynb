# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
#importing libraries

# %%
os.environ['KMP_DUPLICATE_LIB_OK']='True'
#Sets an environment variable to prevent duplication issues

# %%
train_dir = 'D:\\malware\\data_224_g\\data_224_g\\train'
val_dir = 'D:\\malware\\data_224_g\\data_224_g\\val'
# paths of train and validation directory of the Microsoft Malware Classification Challenge (BIG 2015)

# %%
img_height, img_width = 224, 224  # image size
batch_size = 32

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)
#data processing starts from here (pre-processing)

# %%
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical'
)
#data processing (pre-processing)
# Out:
# Found 8684 images belonging to 9 classes.

# %%
validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical'
)
# pre-processing ends here (pre-processing)
# Out:
# Found 2176 images belonging to 9 classes.

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(9, activation='softmax')  # Output layer for 9 classes
])
#CNN model

# %%
#model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
import tensorflow as tf
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.optimizers import SGD

# Create an instance of the SGD optimizer with specific learning rate and momentum
opt = SGD(learning_rate=0.01, momentum=0.9)

# Compile the model with the SGD optimizer
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy',Precision(name='precision'), 
        Recall(name='recall')])

#compiling model in the above code

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=25,  # Adjust based on your specific needs and early stopping criteria
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size
)
#Training the model
# Out:
# Epoch 1/25
# 271/271 [==============================] - 338s 1s/step - loss: 1.4393 - accuracy: 0.5095 - precision: 0.6968 - recall: 0.3044 - val_loss: 0.9385 - val_accuracy: 0.6852 - val_precision: 0.7572 - val_recall: 0.6448
# Epoch 2/25
# 271/271 [==============================] - 262s 966ms/step - loss: 1.0275 - accuracy: 0.6751 - precision: 0.7822 - recall: 0.5604 - val_loss: 1.2570 - val_accuracy: 0.5735 - val_precision: 0.6863 - val_recall: 0.4384
# Epoch 3/25
# 271/271 [==============================] - 242s 893ms/step - loss: 1.1897 - accuracy: 0.6001 - precision: 0.7262 - recall: 0.4293 - val_loss: 0.6991 - val_accuracy: 0.7711 - val_precision: 0.8500 - val_recall: 0.7238
# Epoch 4/25
# 271/271 [==============================] - 236s 871ms/step - loss: 0.7400 - accuracy: 0.7653 - precision: 0.8475 - recall: 0.6860 - val_loss: 0.5968 - val_accuracy: 0.7992 - val_precision: 0.8516 - val_recall: 0.7619
# Epoch 5/25
# 271/271 [==============================] - 235s 865ms/step - loss: 0.6329 - accuracy: 0.8034 - precision: 0.8708 - recall: 0.7438 - val_loss: 0.4550 - val_accuracy: 0.8511 - val_precision: 0.8927 - val_recall: 0.8102
# Epoch 6/25
# 271/271 [==============================] - 236s 870ms/step - loss: 0.5354 - accuracy: 0.8336 - precision: 0.8837 - recall: 0.7870 - val_loss: 0.4141 - val_accuracy: 0.8686 - val_precision: 0.9002 - val_recall: 0.8456
# Epoch 7/25
# 271/271 [==============================] - 247s 913ms/step - loss: 0.5051 - accuracy: 0.8450 - precision: 0.8917 - recall: 0.8011 - val_loss: 0.4055 - val_accuracy: 0.8736 - val_precision: 0.8988 - val_recall: 0.8534
# Epoch 8/25
# 271/271 [==============================] - 255s 941ms/step - loss: 0.4721 - accuracy: 0.8524 - precision: 0.8970 - recall: 0.8172 - val_loss: 0.5636 - val_accuracy: 0.8557 - val_precision: 0.8990 - val_recall: 0.8341
# Epoch 9/25
# 271/271 [==============================] - 264s 975ms/step - loss: 0.4478 - accuracy: 0.8642 - precision: 0.9020 - recall: 0.8267 - val_loss: 0.4119 - val_accuracy: 0.8860 - val_precision: 0.9113 - val_recall: 0.8594
# Epoch 10/25
# 271/271 [==============================] - 261s 962ms/step - loss: 0.4407 - accuracy: 0.8667 - precision: 0.9056 - recall: 0.8315 - val_loss: 0.3284 - val_accuracy: 0.9026 - val_precision: 0.9405 - val_recall: 0.8791
# Epoch 11/25
# 271/271 [==============================] - 236s 869ms/step - loss: 0.4229 - accuracy: 0.8752 - precision: 0.9088 - recall: 0.8395 - val_loss: 0.3249 - val_accuracy: 0.8966 - val_precision: 0.9214 - val_recall: 0.8782
# Epoch 12/25
# 271/271 [==============================] - 234s 864ms/step - loss: 0.3912 - accuracy: 0.8825 - precision: 0.9129 - recall: 0.8532 - val_loss: 0.3085 - val_accuracy: 0.9076 - val_precision: 0.9264 - val_recall: 0.8911
# Epoch 13/25
# 271/271 [==============================] - 239s 883ms/step - loss: 0.3460 - accuracy: 0.8946 - precision: 0.9191 - recall: 0.8696 - val_loss: 0.4045 - val_accuracy: 0.8971 - val_precision: 0.9235 - val_recall: 0.8713
# Epoch 14/25
# 271/271 [==============================] - 242s 892ms/step - loss: 0.3164 - accuracy: 0.9015 - precision: 0.9242 - recall: 0.8784 - val_loss: 0.2746 - val_accuracy: 0.9278 - val_precision: 0.9405 - val_recall: 0.9154
# Epoch 15/25
# 271/271 [==============================] - 236s 871ms/step - loss: 0.3180 - accuracy: 0.9080 - precision: 0.9314 - recall: 0.8848 - val_loss: 0.3408 - val_accuracy: 0.9145 - val_precision: 0.9271 - val_recall: 0.8938
# Epoch 16/25
# 271/271 [==============================] - 236s 872ms/step - loss: 0.3235 - accuracy: 0.9026 - precision: 0.9260 - recall: 0.8804 - val_loss: 0.2474 - val_accuracy: 0.9256 - val_precision: 0.9398 - val_recall: 0.9182
# Epoch 17/25
# 271/271 [==============================] - 234s 863ms/step - loss: 0.3124 - accuracy: 0.9053 - precision: 0.9296 - recall: 0.8867 - val_loss: 0.2522 - val_accuracy: 0.9292 - val_precision: 0.9439 - val_recall: 0.9200
# Epoch 18/25
# 271/271 [==============================] - 235s 868ms/step - loss: 0.2741 - accuracy: 0.9185 - precision: 0.9402 - recall: 0.9008 - val_loss: 0.6630 - val_accuracy: 0.7495 - val_precision: 0.8365 - val_recall: 0.6981
# Epoch 19/25
# 271/271 [==============================] - 234s 863ms/step - loss: 0.2804 - accuracy: 0.9184 - precision: 0.9382 - recall: 0.8977 - val_loss: 0.2900 - val_accuracy: 0.9306 - val_precision: 0.9446 - val_recall: 0.9164
# Epoch 20/25
# 271/271 [==============================] - 234s 862ms/step - loss: 0.2675 - accuracy: 0.9202 - precision: 0.9379 - recall: 0.9048 - val_loss: 0.4299 - val_accuracy: 0.8387 - val_precision: 0.8890 - val_recall: 0.8097
# Epoch 21/25
# 271/271 [==============================] - 1830s 7s/step - loss: 0.2414 - accuracy: 0.9249 - precision: 0.9436 - recall: 0.9093 - val_loss: 0.3031 - val_accuracy: 0.9044 - val_precision: 0.9423 - val_recall: 0.8704
# Epoch 22/25
# 271/271 [==============================] - 260s 960ms/step - loss: 0.2561 - accuracy: 0.9218 - precision: 0.9403 - recall: 0.9063 - val_loss: 0.3879 - val_accuracy: 0.8369 - val_precision: 0.8572 - val_recall: 0.8222
# Epoch 23/25
# 271/271 [==============================] - 261s 962ms/step - loss: 0.2288 - accuracy: 0.9309 - precision: 0.9481 - recall: 0.9169 - val_loss: 0.3585 - val_accuracy: 0.8745 - val_precision: 0.9145 - val_recall: 0.8410
# Epoch 24/25
# 271/271 [==============================] - 269s 993ms/step - loss: 0.2376 - accuracy: 0.9290 - precision: 0.9451 - recall: 0.9147 - val_loss: 0.2839 - val_accuracy: 0.9223 - val_precision: 0.9576 - val_recall: 0.8828
# Epoch 25/25
# 271/271 [==============================] - 257s 948ms/step - loss: 0.2254 - accuracy: 0.9320 - precision: 0.9501 - recall: 0.9202 - val_loss: 0.2702 - val_accuracy: 0.9320 - val_precision: 0.9443 - val_recall: 0.9196

# %%
accuracy = model.evaluate(validation_generator)
print(f'Accuracy: {accuracy[1] * 100:.2f}%')
print(f'Precision: {accuracy[2] * 100:.2f}%')
print(f'Recall: {accuracy[3] * 100:.2f}%')
f1_score = 2 * (accuracy[2] * accuracy[3]) / (accuracy[2] + accuracy[3] + tf.keras.backend.epsilon())
print(f'F1 Score: {f1_score:.2f}')
#Evaluating the model on the validation data.
# Out:
# 68/68 [==============================] - 11s 163ms/step - loss: 0.2702 - accuracy: 0.9320 - precision: 0.9443 - recall: 0.9196
# Accuracy: 93.20%
# Precision: 94.43%
# Recall: 91.96%
# F1 Score: 0.93

# %%
model.save('multiclass_classification_model.h5')
#Saving the model.

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
